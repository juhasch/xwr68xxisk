# %%
import numpy as np
from pylab import *
from IPython.core.pylabtools import figsize

# %%
data = np.load('heatmap.npy')
data16 = np.load('heatmap16.npy')

# %%
data.shape, data16.shape
# Out:
# ((5990,), (2995,))

# %%
data.dtype, data16.dtype
# Out:
# (dtype('uint8'), dtype('uint16'))

# %%
data[0:20]
# Out:
# array([209,  15, 240,  14, 161,  10,  38,   9, 164,   8, 162,   8, 106,
#          8,  75,   8, 157,   8,  57,   8], dtype=uint8)

# %%
data16[0:20]
# Out:
# array([4049, 3824, 2721, 2342, 2212, 2210, 2154, 2123, 2205, 2105, 2126,
#        2069, 2104, 2374, 2697, 3828, 4265, 4037, 2923, 2474], dtype=uint16)

# %%
figsize(8,8)

# %%
X = 16
Y = 128
print(X*Y)
x = data16[0:X*Y].reshape((Y,X))
#y = data[0:4096].reshape((2*X,Y))
# Out:
# 2048

# %%
imshow(x[0:128,:], interpolation='none')
gca().set_aspect(0.1)

# %%
data16[0:32]
# Out:
# array([4049, 3824, 2721, 2342, 2212, 2210, 2154, 2123, 2205, 2105, 2126,
#        2069, 2104, 2374, 2697, 3828, 4265, 4037, 2923, 2474, 2369, 2151,
#        2143, 1978, 2156, 2037, 2130, 2133, 2356, 2529, 2900, 4041],
#       dtype=uint16)

# %%
x[0:2,:]
# Out:
# array([[4049, 3824, 2721, 2342, 2212, 2210, 2154, 2123, 2205, 2105, 2126,
#         2069, 2104, 2374, 2697, 3828],
#        [4265, 4037, 2923, 2474, 2369, 2151, 2143, 1978, 2156, 2037, 2130,
#         2133, 2356, 2529, 2900, 4041]], dtype=uint16)
